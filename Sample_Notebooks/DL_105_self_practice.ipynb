# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
from sklearn.metrics import accuracy_score, mean_squared_error, log_loss
from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_blobs, make_moons
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook as TN

# %%
data, label=make_blobs(n_samples=3000, n_features=6, centers=6, random_state=0)

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(data,label, stratify=label, random_state=0)

# %%
print(x1_train.shape,x1_test.shape,y1_train.shape,y1_test.shape)
# Out:
# (2250, 6) (750, 6) (2250,) (750,)

# %%
enc=OneHotEncoder()
y1_train_oh=enc.fit_transform(np.expand_dims(y1_train,1)).toarray
y1_test_oh=enc.fit_transform(np.expand_dims(y1_test,1)).toarray

# %%
class FeedForwardNeuralNetwork:
  def __init__(self, ninputs, noutput, hiddenlayer=[2]):
    self.nx=ninputs
    self.ny=noutput
    self.sizes=[self.nx]+hiddenlayer+[self.ny]
    self.nl=self.sizes.length()
    print("{} layers in The neural n"self.nl)
    self.H={}
    self.A={}
    self.W={}
    self.B={}
